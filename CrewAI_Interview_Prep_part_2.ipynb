# %% [markdown]
# <a href="https://colab.research.google.com/github/Shankar1371/Crewai_interviewagent/blob/main/CrewAI_Interview_Prep_part_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Setup

# %%
# !pip install 'crewai[tools]' -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.5/89.5 kB 1.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.7/43.7 kB 2.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.5/40.5 kB 2.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.0/52.0 kB 2.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.3/70.3 kB 3.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.1/162.1 kB 4.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 810.1/810.1 kB 10.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 34.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.0/85.0 kB 7.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.9/19.9 MB 54.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 252.4/252.4 kB 20.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.9/46.9 MB 19.4 MB/s eta 0:00:00
# ...

# %%
# %cd /content/drive/MyDrive/AI Agents/CrewAI/Job Interview Prep Part 2
# Out:
# /content/drive/MyDrive/AI Agents/CrewAI/Job Interview Prep Part 2

# %%
#Retrive API keys and store them in the environment variables
from google.colab import userdata
open_api_key = userdata.get('ai_agents_openapi')
serper_api_key = userdata.get('serper_api')

import os
os.environ['OPENAI_API_KEY'] = open_api_key
os.environ['SERPER_API_KEY'] = serper_api_key

# %%
# import libraries
from crewai import Agent, Crew, Process, Task
from langchain_openai import ChatOpenAI
from IPython.display import display, Markdown
from crewai_tools import ScrapeWebsiteTool, SerperDevTool
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_1141/253518168.py in <cell line: 0>()
#       1 # import libraries
#       2 from crewai import Agent, Crew, Process, Task
# ----> 3 from langchain_openai import ChatOpenAI
#       4 from IPython.display import display, Markdown
#       5 from crewai_tools import ScrapeWebsiteTool, SerperDevTool
#
# ModuleNotFoundError: No module named 'langchain_openai'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
#define the LLM
llm = ChatOpenAI(model_name ='gpt-4o', temperature =0.5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1141/4099815919.py in <cell line: 0>()
#       1 #define the LLM
# ----> 2 llm = ChatOpenAI(model_name ='gpt-4o', temperature =0.5)
#
# NameError: name 'ChatOpenAI' is not defined

# %% [markdown]
# User Inputs

# %%
#Call for inputs: Interviewer, comapny, Job position, Job description:
interviewer = input("Enter the name of the interviewer (if unknown include None): ")
company = input("Enter the name of the company: ")
job_position = input("Enter the job position: ")
job_description = input("Enter the job description: ")

# %% [markdown]
# Research AI agents

# %%
#create the Research AI agent
research_agent = Agent(
    role="Research Agent"
    goal="conduct in-depth research"
    backstory =""" As a Research Specialist, Your mission is o uncover detaoled and relevant information. The ultimate goal is to meet the expectations on the task""",
    llm=llm
    tools = [ScrapeWebsiteTool(), SerperDevTool()]
)

# %% [markdown]
# Research Tasks

# %%
#Define the task about researching the comapny
research_comapny_task =Task(
    description= f"""
    Research about {company}. their position in the sector and recent industry trends. Focus on recent news and developements from the last 12 months"""
    expected_output= f""" A comprehensive report in Markdown with bulled point about  {company} and its industry"""
    agent =research_agent
)
# Out:
#   File "/tmp/ipykernel_2998/1503242441.py", line 3
#     description= f"""
#                  ^
# SyntaxError: incomplete input

# %%
#Research Interviewer Task
research_person_task = Task(
    description = f"Research about {interviewer} with focus on their professional career",
    expected_output = f"A comprehensive report in Markdown with bulled point about {interviewer}",
    agent = research_agent
)

# %% [markdown]
# ##AI coach + interviewer

# %%
# Build the AI interview coach agent
coach_agent = Agent(
    role = "Interview Coach",
    goal = f"I help the user prepare for the job interview for job {job_position}",
    backstory = f"You are an expert in job interviews in companies like {company}",
    llm = llm)

# %%
#prepare the list of questions
define_questions_task= Task(
    description = f"""     Define a list a of questions to prepare the user for the job {job_position} based on the company {company}, job description {job_description} and interviewer {interviewer}""",
    expected_output = f"""  a list of 20 questions to ask the user in Markdown format that cover: Culture and Team fit, Job position Fit, Background and ways of working, Growth Mindset""",
    agent = coach_agent,
    context =[research_comapny_task, research_person_task]
)
# Out:
#   File "/tmp/ipykernel_15576/4040649313.py", line 3
#     description =
#     ^
# SyntaxError: expected argument value expression
